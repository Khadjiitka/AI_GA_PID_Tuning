# %%
import os
import sys

print(f"Поточна папка ноутбука: {os.getcwd()}")

#примусово зробить корінням AI_proj
current_dir = os.path.dirname(os.getcwd()) if 'notebooks' in os.getcwd() else os.getcwd()

if current_dir not in sys.path:
    sys.path.insert(0, current_dir)
    
print(f"Корінь проєкту успішно додано в пам'ять: {current_dir}")

from src.database import init_db, save_experiment_result
from src.data_loader import load_telemetry_csv

print("Імпорти повністю відновлено і працюють!")
# Out:
# Поточна папка ноутбука: c:\Users\Gidroid\Desktop\AI_proj\notebooks
# Корінь проєкту успішно додано в пам'ять: c:\Users\Gidroid\Desktop\AI_proj
# Імпорти повністю відновлено і працюють!

# %%
import os
import sys

# Створюємо базу даних (якщо файлу ще немає, він з'явиться в data/processed/)
init_db()

# Пробуємо завантажити наш єдиний рядок даних з CSV 
try:
    df = load_telemetry_csv("test_run_01.csv")
    print("\n[УСПІХ] Дані з CSV завантажено! Ось твій перший датафрейм:")
    print(df)
except Exception as e:
    print(f"\n[ПОМИЛКА] Щось не так із файлом CSV: {e}")

# 3. Імітуємо завершення тесту алгоритмом і записуємо результат в базу даних SQL
# Параметри: Kp=2.1, Ki=0.1, Kd=0.4, версія v1.0, оцінка=92.3 бали, статус='success'
try:
    save_experiment_result(2.1, 0.1, 0.4, "v1.0", 92.3, "success", "test_run_01.csv")
    print("\n[УСПІХ]  Тестовий результат записано.")
except Exception as e:
    print(f"\n[ПОМИЛКА] Щось не так із базою даних: {e}")
# Out:
# Базу даних успішно ініціалізовано за шляхом: C:\Users\Gidroid\Desktop\AI_proj\data\processed\experiments.db
#
# [УСПІХ] Дані з CSV завантажено! Ось твій перший датафрейм:
#        dt  ax_raw  ay_raw  az_raw  gx_raw  gy_raw  gz_raw   ax_g   ay_g  \
# 0  0.9728    -928    -184   16044    -511     307    -101 -0.057 -0.011
#
#     az_g  gyroX_dps  gyroY_dps  gyroZ_dps  roll_deg  pitch_deg  yaw_deg
# 0  0.979       -3.9       2.34      -0.77     -0.66       3.31  -129.13
# Результат експерименту успешно збережено в SQL!
#
# [УСПІХ]  Тестовий результат записано.
